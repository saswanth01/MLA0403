# %% [markdown]
# <a href="https://colab.research.google.com/github/saswanth01/MLA0403/blob/main/LAB/16_20_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 16

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create sample image
img = np.zeros((300, 300), dtype=np.uint8)
cv2.circle(img, (150, 150), 80, 255, -1)

# Thresholding
_, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Morphological operation
kernel = np.ones((5, 5), np.uint8)
morph = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)

# Display
plt.figure(figsize=(10, 3))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(thresh, cmap='gray')
plt.title("Threshold")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(morph, cmap='gray')
plt.title("Morphological")
plt.axis("off")

plt.show()

# %% [markdown]
# 17

# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

X, y = make_classification(
    n_samples=100, n_features=2, n_redundant=0,
    n_clusters_per_class=1, class_sep=2, random_state=42
)

model = LogisticRegression()
model.fit(X, y)

plt.scatter(X[:,0], X[:,1], c=y)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Linear Separability using Logistic Regression")
plt.show()

print("Accuracy:", model.score(X, y))
# Out:
# Accuracy: 1.0

# %% [markdown]
# 18

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 0, 0, 1])

model = MLPClassifier(hidden_layer_sizes=(),
                      activation='identity',
                      solver='lbfgs',
                      random_state=1)

model.fit(X, y)

print("Predictions:", model.predict(X))
print("Accuracy:", model.score(X, y))
# Out:
# Predictions: [0 0 0 1]
# Accuracy: 1.0

# %% [markdown]
# 19

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

X = np.array([
    [0,0], [0,1], [1,0], [1,1],
    [0.5,0.5], [0.2,0.2], [0.8,0.8]
])

y = np.array([0,0,0,0,1,1,1])

model = MLPClassifier(hidden_layer_sizes=(),
                      activation='identity',
                      solver='lbfgs',
                      random_state=1)

model.fit(X, y)

print("Predictions:", model.predict(X))
print("Accuracy:", model.score(X, y))
# Out:
# Predictions: [0 0 0 0 0 0 0]
# Accuracy: 0.5714285714285714

# %% [markdown]
# 20

# %%
from sklearn.datasets import make_classification
from sklearn.neural_network import MLPClassifier

X, y = make_classification(
    n_samples=150, n_features=4,
    n_classes=3, n_informative=3,
    n_redundant=0, random_state=42
)

model = MLPClassifier(hidden_layer_sizes=(),
                      activation='identity',
                      solver='lbfgs',
                      random_state=1)

model.fit(X, y)

print("Predictions:", model.predict(X[:10]))
print("Accuracy:", model.score(X, y))
# Out:
# Predictions: [0 0 0 0 2 1 2 1 0 0]
# Accuracy: 0.6866666666666666
